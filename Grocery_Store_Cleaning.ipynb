# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1ed917f-0c15-4b6d-8a9a-af22ba5172d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1ed917f-0c15-4b6d-8a9a-af22ba5172d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Retail_Food_Stores_20241012.csv")

# %%
df.head()
# Out:
#         County  License Number Operation Type Establishment Type  \
# 0      SUFFOLK          763163          Store                  A
# 1        TIOGA          763162          Store                  A
# 2  WESTCHESTER          763161          Store                  A
# 3      SUFFOLK          763134          Store                  A
# 4        KINGS          763133          Store                  A
#
#                 Entity Name              DBA Name Street Number  \
# 0  HEALTHY MEALS DIRECT LLC  HEALTHY MEALS DIRECT          1866
# 1                  ALDI INC              ALDI #62          1150
# 2   WALGREEN EASTERN CO INC      WALGREENS #21443          3320
# 3         SANJHA BAZAAR LLC         SANJHA BAZAAR          2160
# 4             SKILLMART INC             SKILLMART          1010
#
#         Street Name Address Line 2 Address Line 3              City State  \
# 0     DEER PARK AVE            NaN            NaN         DEER PARK    NY
# ...

# %%
print(df.head())
print(df.info())
print(df.describe())
# Out:
#         County  License Number Operation Type Establishment Type  \
# 0      SUFFOLK          763163          Store                  A
# 1        TIOGA          763162          Store                  A
# 2  WESTCHESTER          763161          Store                  A
# 3      SUFFOLK          763134          Store                  A
# 4        KINGS          763133          Store                  A
#
#                 Entity Name              DBA Name Street Number  \
# 0  HEALTHY MEALS DIRECT LLC  HEALTHY MEALS DIRECT          1866
# 1                  ALDI INC              ALDI #62          1150
# 2   WALGREEN EASTERN CO INC      WALGREENS #21443          3320
# 3         SANJHA BAZAAR LLC         SANJHA BAZAAR          2160
# 4             SKILLMART INC             SKILLMART          1010
#
#         Street Name Address Line 2 Address Line 3              City State  \
# 0     DEER PARK AVE            NaN            NaN         DEER PARK    NY
# ...

# %%
print(df.isnull().sum())
# Out:
# County                    3
# License Number            0
# Operation Type            0
# Establishment Type        0
# Entity Name               0
# DBA Name                  0
# Street Number            61
# Street Name               0
# Address Line 2        23933
# Address Line 3        24220
# City                      1
# State                     0
# Zip Code                  0
# Square Footage         4927
# Georeference              0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#         County  License Number Operation Type Establishment Type  \
# 0      SUFFOLK          763163          Store                  A
# 1        TIOGA          763162          Store                  A
# 2  WESTCHESTER          763161          Store                  A
# 3      SUFFOLK          763134          Store                  A
# 4        KINGS          763133          Store                  A
#
#                 Entity Name              DBA Name Street Number  \
# 0  HEALTHY MEALS DIRECT LLC  HEALTHY MEALS DIRECT          1866
# 1                  ALDI INC              ALDI #62          1150
# 2   WALGREEN EASTERN CO INC      WALGREENS #21443          3320
# 3         SANJHA BAZAAR LLC         SANJHA BAZAAR          2160
# 4             SKILLMART INC             SKILLMART          1010
#
#         Street Name Address Line 2 Address Line 3              City State  \
# 0     DEER PARK AVE            NaN            NaN         DEER PARK    NY
# ...

# %%
filtered_df = df[df['County'] == 'NEW YORK']

# Display the filtered dataframe to verify
print(filtered_df.head())

# Save the filtered dataframe if needed
filtered_df.to_csv('filtered_Grocery_Store_data.csv', index=False)
# Out:
#       County  License Number Operation Type Establishment Type  \
# 15  NEW YORK          762984          Store                  A
# 16  NEW YORK          762969          Store                  A
# 17  NEW YORK          762966          Store                  A
# 18  NEW YORK          762964          Store                  A
# 23  NEW YORK          762819          Store                  A
#
#                      Entity Name                DBA Name Street Number  \
# 15             LUXURY GREENS LLC           LUXURY GREENS          1330
# 16  HUDSON GROUP (HG) RETAIL LLC  HUDSON NEWS STORE #210           NaN
# 17  HUDSON GROUP (HG) RETAIL LLC  HUDSON NEWS STORE #211           NaN
# 18  HUDSON GROUP (HG) RETAIL LLC  HUDSON NEWS STORE #212           NaN
# 23                   CRH RX CORP      QUISQUEYA PHARMACY           174
#
#             Street Name Address Line 2 Address Line 3      City State  \
# 15      5TH AVE STORE 5            NaN            NaN  NEW YORK    NY
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Save the Excel file to your Google Drive
filtered_df.to_excel('/content/drive/My Drive/New_Cleaned_Grocery_Stores.xlsx', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive
